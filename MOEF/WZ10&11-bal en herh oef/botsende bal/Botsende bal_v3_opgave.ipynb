# %% [markdown]
# # De botsende bal

# %% [markdown]
# ## 1. Importeren van de gegevens

# %% [markdown]
# We bestuderen de beweging van een tennisbal die verticaal op de grond botst. Een afstandssensor meet de positie van de tennisbal. De meetsoftware leidt hieruit de snelheid en de versnelling van de tennisbal af. Deze gegevens staan in de .csv-file 'Botsing###.csv' met volgende kolommen
# - Tijd (s)
# - Positie (m)
# - Snelheid (m/s)
# - Versnelling (m/s²)
#
# Onderstaande code leest de data in in het dataframe 'dfBotsing'.
#
# Als voorbereiding op de oefenzitting, moet je opdrachten 2A en 2B oplossen. Hiermee plot je de meetdata op twee verschillende manier op een figuur.

# %%
import math
import numpy as np
import pandas as pd
from qgridnext import show_grid
from slimmeFuncties import *
from extraFunctiesBal import *

dfBotsing = pd.read_csv('Botsing1.csv', sep=';', encoding='latin-1')
display(dfBotsing)
# Out:
#      Tijd (s)  Positie (m)  Snelheid (m/s)  Versnelling (m/s2)
# 0        0.00     0.168114        0.007686           14.336286
# 1        0.01     0.168191        0.151049            5.214486
# 2        0.02     0.169702        0.203194          -47.820102
# 3        0.03     0.171734       -0.275007           68.666022
# 4        0.04     0.168984        0.411653         -107.621094
# ..        ...          ...             ...                 ...
# 495      4.95     0.990555        0.040807            1.184704
# 496      4.96     0.990963        0.052654          -34.536699
# 497      4.97     0.991490       -0.292713           44.664138
# 498      4.98     0.988563        0.153929            0.000000
# 499      4.99     0.990102        0.153929            0.000000
#
# [500 rows x 4 columns]

# %% [markdown]
# ## 2. Visualiseren van de gegevens
#
# Het plotten van gegevens is een handige manier om inzicht te krijgen in wat er gebeurt.
# We gaan in deze opgave dan ook veel plotten waarbij we twee gegevens uit het dataframe naast elkaar zullen zetten.
# Omdat deze gegevens andere eenheden hebben, mogen we die niet op dezelfde y-as zetten.
# Zoals we in de lessen van PIT gezien hebben, kunnen we hiervoor **plt.twinx()** gebruiken.
# Omdat we in deze oefening verschillende keren hetzelfde soort plot gaan maken, hebben we hiervoor een herbruikbare functie geschreven. Je mag de implementatie ervan nalezen in het bestand *extraFunctiesBal.py*, maar dat is niet verplicht.
#
# Het is wél verplicht om die functie **plotTweeKolommen** te kunnen gebruiken.
# Deze neemt volgende parameters:
# - het dataframe waaruit je wil plotten
# - de naam van de kolom die op de linkeras in het rood moet verschijnen
# - de naam van de kolom die op de rechteras in het blauw moet verschijnen
# - een optionele parameter *marker* die beschrijft welke stijl de grafiek moet hebben (zie cursus PIT p. 82), bv. '.', '*', 'o', 's', '8'.
#
# De functie neemt steeds *Tijd (s)* op de x-as.

# %% [markdown]
# **Opdracht 2A** - Gebruik de functie plotTweeKolommen om de positie en snelheid te plotten.

# %%
plotTweeKolommen(1, 2, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 plotTweeKolommen(1, 2, 3)
#
# File ~/BES/MOEF/boting kris a/extraFunctiesBal.py:16, in plotTweeKolommen(data, kolomLinksY, kolomRechtsY, marker)
#       7 def plotTweeKolommen(data, kolomLinksY, kolomRechtsY, marker = None):
#       8     """ maak een figuur met één plot met twee verschillende assen
#       9
#      10     :param data (DataFrame): het dataframe waar de gegevens uit komen
#    (...)     13     :param marker (string, optional): type marker voor de datapunten
#      14     """
# ---> 16     xAs = data['Tijd (s)']
#      17     yAsLinks = data[kolomLinksY]
#      18     yAsRechts = data[kolomRechtsY]
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# **Opdracht 2B** - Gebruik de functie plotTweeKolommen om de snelheid en versnelling te plotten.

# %%
plotTweeKolommen(4, 5, 6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 plotTweeKolommen(4, 5, 6)
#
# File ~/BES/MOEF/boting kris a/extraFunctiesBal.py:16, in plotTweeKolommen(data, kolomLinksY, kolomRechtsY, marker)
#       7 def plotTweeKolommen(data, kolomLinksY, kolomRechtsY, marker = None):
#       8     """ maak een figuur met één plot met twee verschillende assen
#       9
#      10     :param data (DataFrame): het dataframe waar de gegevens uit komen
#    (...)     13     :param marker (string, optional): type marker voor de datapunten
#      14     """
# ---> 16     xAs = data['Tijd (s)']
#      17     yAsLinks = data[kolomLinksY]
#      18     yAsRechts = data[kolomRechtsY]
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# **Opdracht 2C** - Verklaar de vorm van beide grafieken.
#
# Verklaar eerst waarom de positie varieert tussen ongeveer 0,17m en 1m (voor de meetdata Botsing1.csv).
# Beredeneer daarna de waarden van snelheid van versnelling op basis van het verband tussen verplaatsing en snelheid en het verband tussen snelheid en versnelling uit de cursus mechanica van de puntmassa.

# %% [markdown]
# **Antwoord**

# %% [markdown]
# **Opdracht 2D** De grafiek van de snelheid vertoont veel ruis.
#
# Verklaar op basis van de onzekerheidsanalyse.
#
# **Antwoord**
#
#
#
#
# Waarom vertoont de versnelling zulke grote pieken rond een botsing?
#
# **Antwoord**

# %% [markdown]
# ## 3. Voorbereiden van de data

# %% [markdown]
# In drie stappen gaan we nu onze data normaliseren.
#
# 1. We willen dat de positie van de tennisbal overeenkomt met de conventies gebruikt in de cursus mechanica van de puntmassa. De y-as voor de positie moet verticaal omhoog wijzen, weg van het aardoppervlak. Een hoogte $h$ = 0 m moet betekenen dat de tennisbal op de grond is, en de maximale waarde moet overeenstemmen met de maximale afstand van de grond.
# 2. Als je inzoomt op de voorgaande grafieken, zie je veel ruis, vooral bij de snelheid. We wensen deze ruis te verminderen door een wiskundige techniek toe te passen op de meetdata.
# 3. We willen het eerste deel waarin de bal nog niet losgelaten is, verwijderen uit de dataset. De dataset moet starten op het moment dat de bal wordt losgelaten.
#
# Om te kunnen vergelijken met het originele dataframe lezen we eerst de dataset opnieuw.

# %%
dfBotsingt0 = pd.read_csv('Botsing1.csv', sep=';', encoding='latin-1')

# %% [markdown]
# **Opdracht 3A** - Pas dit nieuwe dataframe aan zodat de positie op de y-as naar boven wijst. Hiermee bedoelen we dathet nulpunt samenvalt met een positie op de grond en dat grotere waarden overeenkomen met een positie verder van de grond.
#
# Plot het aangepaste dataframe ter controle.
#
# Denk ook na of je de snelheid en versnelling moet aanpassen aan deze nieuwe y-as! Pas die indien nodig aan.

# %%
dfBotsingt0=7

# %% [markdown]
# **Opdracht 3B** Selecteer een functie uit de bibliotheek slimmeFuncties om de ruis in de meting te verminderen.
# * Leg in woorden uit wat deze functie precies doet
# * Welke invloed heeft deze parameter?

# %% [markdown]
# **Antwoord**

# %% [markdown]
# **Opdracht 3C** Kies de geschikte parameters voor de functie en pas ze correct toe. Voeg in de dataframe nieuwe kolommen toe voor de hoogte en snelheid met verminderde ruis.
# Plot de grafiek om te controleren of deze techniek de ruis onderdrukt.
#
# Experimenteer met de parameters van de functie en verklaar wat er gebeurt met de positie en snelheid van de bal.

# %% [markdown]
# **Opdracht 3D** - Selecteer enkel de gegevens vanaf het loslaten van de bal. (werk vanaf nu enkel op de originele data, met ruis)

# %%
dfBotsingt0 = 11

# %% [markdown]
# Als je het goed gedaan hebt, zie je in bovenstaande grafiek dat de tijdsas een stuk voorbij de 0 begint te lopen.
#
# **Opdracht 3E**
# - Sla het begin van de tijdsas op in een variabele **t0**.
# - Herdefinieer de tijdsas zodat de start van het vallen overeenkomt met $t = 0$ s.

# %%
t0 = 12

# %% [markdown]
# **Opdracht 3F** - Vanaf welke tijdstip begint de bal te vallen en vanaf welke hoogte is dit?
#
# Druk het antwoord op het scherm in een mooie antwoordzin.
# Tip: gebruik voor het tijdstip de variabele die je in opdracht 3C gedefinieerd hebt.

# %%
hoogte = 13

# %% [markdown]
# ## 4. Selecteren van de beweging tussen twee botsingen

# %% [markdown]
# In de analyse hieronder zijn we vooral geïnteresseerd in de beweging tussen de twee botsingen van grond tot grond.
#
# De voorgaande fase van het loslaten van de tennisbal tot de eerste botsing noemen we 'Fase 0'.
# Elke daaropvolgende op-en-neer gaande beweging noemen we 'Fase 1', 'Fase 2',  etc.

# %% [markdown]
# **Opdracht 4A** - Selecteer de gegevens voor 'Fase 0' door een criterium te formuleren op basis van de **positie** en plot de grafiek voor de positie en de snelheid van 'Fase 0'.

# %% [markdown]
# Omschrijf in woorden een strategie (= precieze formulering welke berekening je moet uitvoeren) om dit te realiseren.
# Formuleer minstens twee verschillende strategieën (Antwoord 1 en Antwoord 2).

# %% [markdown]
# **Antwoord 1**
#
# ...
#
# **Antwoord 2**
#
# ...

# %% [markdown]
# Implementeer nu de code en plot het dataframe ter controle. Voeg op de plot een marker toe om alle meetpunten expliciet zichtbaar te maken.
#
# Maak ook de plot van de versnelling in 'Fase 0', deze hebben we later nodig.

# %%
dfFase0Pos = 14

dfFase0Pos_v2 = 15

# %% [markdown]
# **Opdracht 4B**
#
# Test de code die je tot nu toe geschreven hebt op 2 andere datasets:
#
# * botsing2.csv
# * botsing3.csv
#
# Voert de code nog steeds de juiste selecties en berekeningen uit? Pas de parameters aan indien nodig.

# %% [markdown]
# **Extra Opdracht 4C** - Selecteer de gegevens voor 'Fase 0' door een criterium te formuleren op basis van de **snelheid**.

# %% [markdown]
# Omschrijf in woorden een strategie (= precieze formulering welke berekening je moet uitvoeren) om dit te realiseren.

# %% [markdown]
# **Antwoord**

# %% [markdown]
# Implementeer nu de code en plot het dataframe ter controle. Voeg op de plot opnieuw een marker toe om alle meetpunten expliciet zichtbaar te maken. Maak ook de plot van de versnelling in 'Fase 0': deze hebben we later nodig.

# %%
dfFase0Snel = 16

# %% [markdown]
# **Extra Opdracht 4D** - Verklaar de verschillen tussen de verschillende manieren van selecteren.

# %% [markdown]
# **Antwoord**

# %% [markdown]
# **Extra Opdracht 4E** - Selecteer de gegevens voor 'Fase 1' door gebruik te maken van de positie en plot de grafiek voor de positie en de snelheid.
#
# Enkele tips:
# - In 'Fase 1' varieert de positie van een minimale waarde over een maximale waarde terug naar een minimale waarde.
# - In de bibliotheek slimmeFuncties.py zitten wel functies om te selecteren of te knippen tot een eerste lokaal maximum, maar geen functies om te selecteren tot aan een tweede lokaal maximum.
# - Je kan wel twee keer knippen en dan opvragen op welke tijd je dan zit.
# - Vervolgens kan je met de filter van het dataframe alle rijen selecteren met een kleinere tijd. In de lessen van PIT hebben we bijvoorbeeld alle rijen geselecteerd met weinig stroom via *dfVeelStroom = df[ df["I"] < 1.0 ].

# %% [markdown]
# Omschrijf in woorden een strategie (= precieze formulering welke berekening je moet uitvoeren).

# %% [markdown]
# **Antwoord**

# %% [markdown]
# Implementeer nu de code en plot het dataframe ter controle. Voeg op de plot een marker toe om alle meetpunten expliciet zichtbaar te maken.
#
# Zorg ervoor dat ook in dit dataframe de tijdsas start bij $t = 0$ s. Mogelijk krijg je een *warning*, maar deze mag je negeren.

# %%
# opgelet: de versie met knipTotLokaalExtremum werkt niet, deze knipt de eerste helft van fase 1, maar niet de volledige fase 1.
#beginFase1 = knipTotLokaalExtremum(dfBotsingt0, 'Positie (m)')
#middenFase1 = knipTotLokaalExtremum(beginFase1, 'Positie (m)')
#eindeFase1 = knipTotLokaalExtremum(middenFase1, 'Positie (m)')  

beginFase1 = 17
middenFase1 = 18
eindeFase1 = 19 

fase1 = 20

# %% [markdown]
# ## 5. Bepalen van de valversnelling

# %% [markdown]
# Een goede manier om de kwaliteit van deze meting te beoordelen is de bepaling van de versnelling. Deze moet overeenkomen met de valversnelling ($g$ = 9,81 m/s²). Indien de versnelling erg afwijkt is dat een indicatie dat er iets fout is met de meetresultaten.
# We bepalen de versnelling aan de hand van 'Fase 0'.

# %% [markdown]
# **Opdracht 5A**
# Bereken de versnelling als het gemiddelde van de kolom versnelling in het dataframe van Fase 0.

# %%
print('De gemiddelde versnelling in Fase 0 is')
# Out:
# De gemiddelde versnelling in Fase 0 is

# %% [markdown]
# **Opdracht 5B**
#
# Er is een veel betere manier om de versnelling uit deze metingen te bepalen.
#
# * Fit een veeltermfunctie (= een *model*) van een geschikte graad door de meetpunten positie in functie van de tijd voor Fase 0.
#
# * De parameters van de veeltermfunctie hebben ook een fysische betekenis volgens onderstaande vergelijkingen. Leg de link met de forumles uit de cursus mechanica van de puntmassa en ga na welke grootheden je uit deze parameters kan afleiden.
#
# $y = y_0 + v_{0y}\cdot(t-t_0) - \dfrac{g \cdot (t - t_0)^2}{2}$ waarbij we de tijdsas zodanig hebben bepaald dat $t_0=0$ s
# dus
# $y = y_0 + v_{0y}\cdot t - \dfrac{g \cdot t^2}{2}$
#
# * Interpreteer geïdentificeerde grootheden. Zijn dit realistische waardes?

# %%
fitPos0 = 21
print('De versnelling is ')
print('De beginsnelheid is ' )
print('De beginpositie is ' )
# Out:
# De versnelling is
# De beginsnelheid is
# De beginpositie is

# %% [markdown]
# Conroleer het model door de model op de meetdata te plotten. De code voor deze plot krijgen jullie van ons.

# %%
plt.figure()
yAs2 = list(map(fitPos0,dfFase0Pos['Tijd (s)']))
plt.plot(dfFase0Pos['Tijd (s)'], yAs2, color = 'red' , label='model')
plt.plot(dfFase0Pos['Tijd (s)'],dfFase0Pos['Positie (m)'], color="black",marker='.',linestyle='', label="meting")
plt.legend()
plt.xlabel("Tijd (s)")
plt.ylabel("Positie (m)")
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 plt.figure()
# ----> 2 yAs2 = list(map(fitPos0,dfFase0Pos['Tijd (s)']))
#       3 plt.plot(dfFase0Pos['Tijd (s)'], yAs2, color = 'red' , label='model')
#       4 plt.plot(dfFase0Pos['Tijd (s)'],dfFase0Pos['Positie (m)'], color="black",marker='.',linestyle='', label="meting")
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# **Extra opdracht 5B** Bepaal de waarde van de valversnelling voor 'Fase 1' door de gepast model te fitten op de gemeten posities in 'Fase 1'. Plot ook het model over de meetdata ter vontrole en interpreteer ook de parameters.

# %%
fitPos1 = 22

# %% [markdown]
# ## 6. Restitutiecoëfficiënt

# %% [markdown]
# We berekenen de restitutiecoëfficiënt (zie cursus) van de botsingen.

# %% [markdown]
# **Opdracht 6A** - Maak een figuur met de positie en snelheid van de tennisbal rond de eerste botsing. Op de figuur dienen een 10-tal punten net voor en net na de botsing te staan.

# %%
dfBotsing1hulp=23

# %% [markdown]
# **Opdracht 6B** - Omschrijf in woorden een strategie (= precieze formulering welke berekening je moet uitvoeren) om de restitutiecoëfficiënt *k* te bepalen. Hoe bereken je zo nauwkeurig mogelijk de snelheid net voor en na de botsing?

# %% [markdown]
# **Antwoord**

# %% [markdown]
# Implementeer de voorgaande strategie in code en bereken de restitutiecoëfficiënt *k*. Pas eventueel in opdracht 6A het aantal punten voor en na de botsing aan zodat dit overeenkomt met de gekozen strategie.

# %%
snelheidVoorGem = 24

snelheidNaGem = 25
restCoeff = 26

print('De restitutiecoëfficiënt is ')
# Out:
# De restitutiecoëfficiënt is

# %% [markdown]
# **Extra Opdracht 6C** - Bereken de restitutiecoëfficiënt  voor de botsing tussen Fase 0 en Fase 1 door gebruikt te maken van de bereikte hoogte voor en na de botsing. Dit kan je doen door het principe van het behoud van mechanische energie toe te passen voor en na de botsing.
#
# Met deze aanpak verwaarloos je een belangrijk effect, welk effect?
#
# Vergelijk deze uitkomst met de restitutiecoëfficiënt berekend in de vorige opdracht en verklaar de verschillen.

# %% [markdown]
# **Antwoord**

# %%
HoogteVoor=27
print('De maximale hoogte voor de botsing is')

HoogteNa=28
print('De maximale hoogte na de botsing is')

restCoeffH=29
print('De restitutiecoëfficiënt op basis van de hoogtes is ')
# Out:
# De maximale hoogte voor de botsing is
# De maximale hoogte na de botsing is
# De restitutiecoëfficiënt op basis van de hoogtes is

# %% [markdown]
# ## 7 Resultaten van meerdere metingen verwerken
#
# **Opdracht 7**
#
# Test nu de volledige code voor de 2 andere datasets:
#
# * botsing2.csv
# * botsing3.csv
#
# Voert de code nog steeds de juiste selecties en berekeningen uit? Pas de parameters aan indien nodig.
